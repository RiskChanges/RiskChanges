# %%
Samle of the data management modulle

# %%
from RiskChanges import DataManage

# %%
DataManage.loadshp(shpInput="D:\SDSS\Sample data\Split_one\Flood_Class.shp",
        connstr='postgresql://postgres:puntu@localhost:5432/postgres',lyrName='Tekson',schema='tekson')

# %%
DataManage.LoadWFS(wfsURL="http://geo.stat.fi/geoserver/vaestoruutu/wfs",layer_name='vaestoruutu:vaki2005_1km_kp',connstr='postgresql://postgres:puntu@localhost:5432/postgres',lyrName='Tekson_WFS',schema='tekson')
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterValue                     Traceback (most recent call last)
# ~\.conda\envs\SDSS\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1257                     self.dialect.do_executemany(
# -> 1258                         cursor, statement, parameters, context
#    1259                     )
#
# ~\.conda\envs\SDSS\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# InvalidParameterValue: Geometry type (Point) does not match column type (MultiPolygon)
#
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
x, y = 174100, 444100
bbox = (x-500, y-500, x+500, y+500)
DataManage.loadWCS(folder="D:/",out_name='ashok_WCS',WCS_URL='http://geodata.nationaalgeoregister.nl/ahn2/wcs?service=WCS',Version='1.0.0',layerName='ahn2_05m_ruw',bbox=bbox,srid=28992)
